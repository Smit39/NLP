# %% [markdown]
# Tried it using only 10k rows as it was taking very very long

# %%
# !pip install bertopic

# %%
from bertopic import BERTopic

# %%
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from wordcloud import WordCloud
from collections import defaultdict
from wordcloud import STOPWORDS
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.decomposition import TruncatedSVD
import matplotlib.pyplot as plt

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def cleanse(string):
    # Lower casing
    string = str(string).lower()

    # Getting rid of mentions
    string = re.sub(r"@\S+", " ", string)

    # Removing HTML
    string = re.sub(r"&.*?;|<.*?>", " ", string)

    # URL removal
    string = re.sub(r"https?://\S+|www\.\S+", " ", string)

    # Handling abbreviations
    # string = convert_abbrev_in_text(string)

    # Non-word removals (special chars)
    string = re.sub(r"[^a-z]", " ", string)

    # Stop word removal
    string = " ".join(word for word in nltk.tokenize.word_tokenize(string) if word not in nltk.corpus.stopwords.words('english'))

    # Lemmatization
    lemma = nltk.stem.WordNetLemmatizer()
    string = " ".join(lemma.lemmatize(word) for word in nltk.tokenize.word_tokenize(string))

    # Single char removal
    string = re.sub(r"\b\w\b", "", string).strip()

    return string

# %%
df = pd.read_csv('Reviews10k.csv')

# %%
df.head()
# Out:
#                                                 Text
# 0  We have used Thai Kitchen Peanut sauce many ti...
# 1  I love this product and I share it with my fam...
# 2  I love tea. I drink 4-6 cups a day. I've been ...
# 3  I purchased this coffee because both the Newma...
# 4  These garlic cloves are amazing! I snack on th...

# %%
# Example usage
text_to_clean = "This is an example text with @mentions, <html> tags, and https://example.com links."
cleaned_text = cleanse(text_to_clean)
print(cleaned_text)
# Out:
# example text tag link

# %%
df['cleaned']=df['Text'].apply(cleanse)

# %%
docs = list(df.loc[:,'cleaned'].values)

# %%
docs[:5]
# Out:
# ['used thai kitchen peanut sauce many time love chicken shrimp hard find started looking online best price packing well done glass jar little worried also worried expiration date food jar good well next year worry either good experience',
#  'love product share family co worker jv way amazon best online purchase definitely continue buy currently preparing third order many month great upset stomach sore throat stressful day cool night make hot water milk take chill',
#  'love tea drink cup day tea snob usually make tea loose leaf sometimes prefer convenience tea bag really liked mint blend tea although usually drink green tea find black tea welcome change every also found extra energy kick tea refreshing give jitter would definitely use',
#  'purchased coffee newman sumatran reserve priced near per  cup month needed something dark bold replace price came back coffee brewed strong bit empty bitter finish caffeine content acceptable package could treated little better shipping lot dent crushed corner side evidence bending side  cup none cup thus far shown broken seal though overall acceptable extra bold style  cup better option favorite newman sumatran reserve tried black diamond  cup bit pricey right also probably end using coupon buying preferred flavor brick mortar store nearby better price ordering coffee people count extra bold flavor box pretty stable pricing past month option cheaper substitute pricier extra bold flavor wish amazon could sort supply issue keep  cup price little stable lastly buy similar priced option tl dr okay go extra bold flavor priced',
#  'garlic clove amazing snack right jar think nothing ordering case sent way hawaiian island kaua yes good love garlic even check little morsel white gold sorry']

# %% [markdown]
# # BERTopic

# %%
vectorizer_model = CountVectorizer(min_df=2)
topic_model = BERTopic(nr_topics=10)
topics, probs = topic_model.fit_transform(docs)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %% [markdown]
# # View Topics

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                              Name  \
# 0     -1   3057        -1_like_product_taste_good
# 1      0   5194           0_coffee_tea_taste_like
# 2      1    713              1_cat_food_dog_treat
# 3      2    521    2_product_amazon_order_arrived
# 4      3    262           3_baby_milk_formula_son
# 5      4    104  4_hair_shampoo_conditioner_scalp
# 6      5     44              5_china_fda_made_dog
# 7      6     43             6_wine_kit_herb_yeast
# 8      7     34            7_trap_fly_gopher_moth
# 9      8     28             8_tea_sleep_cough_eye
#
#                                       Representation  \
# 0  [like, product, taste, good, great, flavor, on...
# 1  [coffee, tea, taste, like, flavor, good, great...
# 2  [cat, food, dog, treat, love, one, like, toy, ...
# 3  [product, amazon, order, arrived, box, plant, ...
# 4  [baby, milk, formula, son, organic, month, lov...
# 5  [hair, shampoo, conditioner, scalp, oil, use, ...
# 6  [china, fda, made, dog, product, gmo, treat, j...
# 7  [wine, kit, herb, yeast, oak, bottle, gallon, ...
# 8  [trap, fly, gopher, moth, ant, dust, sticky, w...
# 9  [tea, sleep, cough, eye, calm, help, also, thr...
#
#                                  Representative_Docs
# 0  [flavor tea light even though steeped long tim...
# 1  [drink lot tea dollar store plain black tea ex...
# 2  [felt needed review cat food getting one star ...
# 3  [great product great price arrived time packag...
# 4  [much research formula best child wanted choos...
# 5  [first review shampoo colored damaged hair ver...
# 6  [ordered three package price good saw asking a...
# 7  [blended week chianti rosso wine kit blended w...
# 8  [reading article gardening forum regarding dif...
# 9  [tea great lot stress lately tea definitely he...

# %% [markdown]
# # trying to fine tune

# %%
vectorizer_model = CountVectorizer(stop_words="english", ngram_range=(1, 3), max_df=0.95, min_df=2)
topic_model.update_topics(docs, vectorizer_model=vectorizer_model) #straight update no need to retrain

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                              Name  \
# 0     -1   3057         -1_taste_flavor_love_food
# 1      0   5194         0_coffee_tea_taste_flavor
# 2      1    713              1_cat_food_dog_treat
# 3      2    521      2_arrived_box_plant_received
# 4      3    262           3_baby_milk_formula_son
# 5      4    104  4_hair_shampoo_conditioner_scalp
# 6      5     44               5_china_fda_dog_gmo
# 7      6     43             6_wine_kit_herb_yeast
# 8      7     34               7_trap_fly_ant_dust
# 9      8     28             8_tea_sleep_cough_eye
#
#                                       Representation  \
# 0  [taste, flavor, love, food, dog, bag, sugar, b...
# 1  [coffee, tea, taste, flavor, cup, love, chocol...
# 2  [cat, food, dog, treat, love, dog food, toy, e...
# 3  [arrived, box, plant, received, ordered, shipp...
# 4  [baby, milk, formula, son, organic, love, old,...
# 5  [hair, shampoo, conditioner, scalp, oil, cocon...
# 6  [china, fda, dog, gmo, treat, jerky, chicken j...
# 7  [wine, kit, herb, yeast, gallon, basil, fermen...
# 8  [trap, fly, ant, dust, sticky, set, catch, hol...
# 9  [tea, sleep, cough, eye, calm, help, throat, p...
#
#                                  Representative_Docs
# 0  [flavor tea light even though steeped long tim...
# 1  [drink lot tea dollar store plain black tea ex...
# 2  [felt needed review cat food getting one star ...
# 3  [great product great price arrived time packag...
# 4  [much research formula best child wanted choos...
# 5  [first review shampoo colored damaged hair ver...
# 6  [ordered three package price good saw asking a...
# 7  [blended week chianti rosso wine kit blended w...
# 8  [reading article gardening forum regarding dif...
# 9  [tea great lot stress lately tea definitely he...

# %%
# topic_labels = topic_model.generate_topic_labels(nr_words = 10,topic_prefix = False, separator = " - ")
# topic_model.set_topic_labels(topic_labels)
# topic_model.get_topic_info()

# %%
topic_model.get_document_info(docs)
# Out:
#                                                Document  Topic  \
# 0     used thai kitchen peanut sauce many time love ...     -1
# 1     love product share family co worker jv way ama...     -1
# 2     love tea drink cup day tea snob usually make t...      0
# 3     purchased coffee newman sumatran reserve price...      0
# 4     garlic clove amazing snack right jar think not...      0
# ...                                                 ...    ...
# 9995  would say favorite cereal one super filling su...      0
# 9996  like hummus stuff nearly good fresh tired quic...     -1
# 9997  great treat schnauzer love however make sure m...      5
# 9998  got gel time box little dented big deal got wi...      2
# 9999  become difficult find senseo pod decided give ...      0
#
#                               Name  \
# 0        -1_taste_flavor_love_food
# 1        -1_taste_flavor_love_food
# 2        0_coffee_tea_taste_flavor
# 3        0_coffee_tea_taste_flavor
# 4        0_coffee_tea_taste_flavor
# ...                            ...
# 9995     0_coffee_tea_taste_flavor
# 9996     -1_taste_flavor_love_food
# 9997           5_china_fda_dog_gmo
# 9998  2_arrived_box_plant_received
# 9999     0_coffee_tea_taste_flavor
#
#                                              CustomName  \
# 0     taste - flavor - love - food - dog - bag - sug...
# 1     taste - flavor - love - food - dog - bag - sug...
# 2     coffee - tea - taste - flavor - cup - love - c...
# 3     coffee - tea - taste - flavor - cup - love - c...
# 4     coffee - tea - taste - flavor - cup - love - c...
# ...                                                 ...
# 9995  coffee - tea - taste - flavor - cup - love - c...
# 9996  taste - flavor - love - food - dog - bag - sug...
# 9997  china - fda - dog - gmo - treat - jerky - chic...
# 9998  arrived - box - plant - received - ordered - s...
# 9999  coffee - tea - taste - flavor - cup - love - c...
#
#                                          Representation  \
# 0     [taste, flavor, love, food, dog, bag, sugar, b...
# 1     [taste, flavor, love, food, dog, bag, sugar, b...
# 2     [coffee, tea, taste, flavor, cup, love, chocol...
# 3     [coffee, tea, taste, flavor, cup, love, chocol...
# 4     [coffee, tea, taste, flavor, cup, love, chocol...
# ...                                                 ...
# 9995  [coffee, tea, taste, flavor, cup, love, chocol...
# 9996  [taste, flavor, love, food, dog, bag, sugar, b...
# 9997  [china, fda, dog, gmo, treat, jerky, chicken j...
# 9998  [arrived, box, plant, received, ordered, shipp...
# 9999  [coffee, tea, taste, flavor, cup, love, chocol...
#
#                                     Representative_Docs  \
# 0     [flavor tea light even though steeped long tim...
# 1     [flavor tea light even though steeped long tim...
# 2     [drink lot tea dollar store plain black tea ex...
# 3     [drink lot tea dollar store plain black tea ex...
# 4     [drink lot tea dollar store plain black tea ex...
# ...                                                 ...
# 9995  [drink lot tea dollar store plain black tea ex...
# 9996  [flavor tea light even though steeped long tim...
# 9997  [ordered three package price good saw asking a...
# 9998  [great product great price arrived time packag...
# 9999  [drink lot tea dollar store plain black tea ex...
#
#                                             Top_n_words  Probability  \
# 0     taste - flavor - love - food - dog - bag - sug...     0.000000
# 1     taste - flavor - love - food - dog - bag - sug...     0.000000
# 2     coffee - tea - taste - flavor - cup - love - c...     0.854951
# 3     coffee - tea - taste - flavor - cup - love - c...     1.000000
# 4     coffee - tea - taste - flavor - cup - love - c...     0.982436
# ...                                                 ...          ...
# 9995  coffee - tea - taste - flavor - cup - love - c...     1.000000
# 9996  taste - flavor - love - food - dog - bag - sug...     0.000000
# 9997  china - fda - dog - gmo - treat - jerky - chic...     0.590525
# 9998  arrived - box - plant - received - ordered - s...     1.000000
# 9999  coffee - tea - taste - flavor - cup - love - c...     1.000000
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 9995                    False
# 9996                    False
# 9997                    False
# 9998                    False
# 9999                    False
#
# [10000 rows x 9 columns]

# %%
topic_model.get_topic_freq()
# Out:
#    Topic  Count
# 1      0   5194
# 0     -1   3057
# 3      1    713
# 4      2    521
# 5      3    262
# 2      4    104
# 7      5     44
# 8      6     43
# 9      7     34
# 6      8     28

# %%
topic_model.get_topic(3)
# Out:
# [('baby', 0.06292980341837269),
#  ('milk', 0.05969024035000255),
#  ('formula', 0.047611211572692276),
#  ('son', 0.03143695613619083),
#  ('organic', 0.029902093606828176),
#  ('love', 0.027865180617748713),
#  ('old', 0.025904653729729953),
#  ('kid', 0.025298340190530646),
#  ('food', 0.025099937439142603),
#  ('daughter', 0.024854483022166134)]

# %%
for i in range(-1, 9):
    topic = topic_model.get_topic(i)
    words = [word for word, _ in topic]  # Extracting words, ignoring weights
    print(f"Topic {i}: {', '.join(words)}")
# Out:
# Topic -1: taste, flavor, love, food, dog, bag, sugar, buy, sweet, box
# Topic 0: coffee, tea, taste, flavor, cup, love, chocolate, best, drink, sugar
# Topic 1: cat, food, dog, treat, love, dog food, toy, eat, cat food, pill
# Topic 2: arrived, box, plant, received, ordered, shipping, item, flower, buy, service
# Topic 3: baby, milk, formula, son, organic, love, old, kid, food, daughter
# Topic 4: hair, shampoo, conditioner, scalp, oil, coconut, skin, coconut oil, clear, smell
# Topic 5: china, fda, dog, gmo, treat, jerky, chicken jerky, chicken, company, kellogg
# Topic 6: wine, kit, herb, yeast, gallon, basil, fermentation, garden, batch, fresh
# Topic 7: trap, fly, ant, dust, sticky, set, catch, hole, wire, area
# Topic 8: tea, sleep, cough, eye, calm, help, throat, pain, drinking, sleep aid

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a78f2572-b754-4b20-9989-5adea36715f0" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a78f2572-b754-4b20-9989-5adea36715f0")) {                    Plotly.newPlot(                        "a78f2572-b754-4b20-9989-5adea36715f0",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01824917311035174,0.027218050905230613,0.031186968981466227,0.0313779768197208,0.035830656144662645],"y":["cup  ","flavor  ","taste  ","tea  ","coffee  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.033108935823949505,0.04720509901633515,0.08541334977888926,0.08596010193813726,0.0864415496372199],"y":["love  ","treat  ","dog  ","food  ","cat  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.02582221327084598,0.025836937591062075,0.027259533914776396,0.0285700061522227,0.03272433836968569],"y":["ordered  ","received  ","plant  ","box  ","arrived  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.029902093606828176,0.03143695613619083,0.047611211572692276,0.05969024035000255,0.06292980341837269],"y":["organic  ","son  ","formula  ","milk  ","baby  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.06887257657038041,0.07387118364047925,0.10188605399082354,0.14678009922536991,0.20214969716193196],"y":["oil  ","scalp  ","conditioner  ","shampoo  ","hair  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.05089243907390665,0.0523280958242894,0.07500404448168276,0.07655110179423055,0.1346076315285698],"y":["treat  ","gmo  ","dog  ","fda  ","china  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.0363457258459294,0.06703197703198398,0.0911384184501239,0.10548586160465666,0.21382105045310495],"y":["gallon  ","yeast  ","herb  ","kit  ","wine  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.06372565258448802,0.0673081551390069,0.08474461520862368,0.09392620090654565,0.18552610677482834],"y":["sticky  ","dust  ","ant  ","fly  ","trap  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666 ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eafec9b3-5bac-425f-8cf5-597b493ea63d" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eafec9b3-5bac-425f-8cf5-597b493ea63d")) {                    Plotly.newPlot(                        "eafec9b3-5bac-425f-8cf5-597b493ea63d",                        [{"customdata":[[0,"coffee | tea | taste | flavor | cup",5194],[1,"cat | food | dog | treat | love",713],[2,"arrived | box | plant | received | ordered",521],[3,"baby | milk | formula | son | organic",262],[4,"hair | shampoo | conditioner | scalp | oil",104],[5,"china | fda | dog | gmo | treat",44],[6,"wine | kit | herb | yeast | gallon",43],[7,"trap | fly | ant | dust | sticky",34],[8,"tea | sleep | cough | eye | calm",28]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[5194,713,521,262,104,44,43,34,28],"sizemode":"area","sizeref":3.24625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[3.153446912765503,-17.512651443481445,2.742612600326538,2.3851215839385986,2.6551759243011475,-17.69942283630371,3.3077328205108643,2.0015783309936523,3.974304676055908],"xaxis":"x","y":[-7.541580677032471,-18.24542236328125,-6.814395904541016,-7.283863544464111,-8.174467086791992,-18.43220329284668,-7.965668201446533,-7.106415271759033,-7.739879131317139],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"o ...

# %%
# topic_model.visualize_hierarchy()
